# %%
import pandas as pd

# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd

# %%
import pandas as pd 
df = pd.read_csv('orders.csv',na_values=['Not availabel','unknown'])
print(df["Ship Mode"].unique())
# Out:
# <StringArray>
# [  'Second Class', 'Standard Class',  'Not Available',              nan,
#     'First Class',       'Same Day']
# Length: 6, dtype: str

# %%
df.columns = df.columns.str.strip()          # Remove leading/trailing spaces
df.columns = df.columns.str.lower()          # Convert to lowercase
df.columns = df.columns.str.replace(' ', '_') # Replace spaces with underscores

print(df.columns.tolist())
# Out:
# ['order_id', 'order_date', 'ship_mode', 'segment', 'country', 'city', 'state', 'postal_code', 'region', 'category', 'sub_category', 'product_id', 'cost_price', 'list_price', 'quantity', 'discount_percent']

# %%
# making the new colunms discount sale price and profit 

df["discount"] = df["list_price"] * df["discount_percent"] / 100
df["sale_price"] = df ["list_price"] - df["discount"]
df["profit"] = df["sale_price"] - df["cost_price"]
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_mode', 'segment', 'country', 'city',
#        'state', 'postal_code', 'region', 'category', 'sub_category',
#        'product_id', 'cost_price', 'list_price', 'quantity',
#        'discount_percent', 'discount', 'sale_price', 'profit'],
#       dtype='str')

# %%
#Convert the type of the date colunm from object to date 
df["order_date"]=pd.to_datetime(df["order_date"], format="%Y-%m-%d")

# %%
# Drop colunms cost price list price and discount percent 
  

df.drop( columns =['cost_price','list_price','discount_percent'],inplace= True)

# %%
pip install sqlalchemy pymysql
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 43.8 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pymysql]my]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import sqlalchemy as sal

# %%
import pandas as pd
import sqlalchemy as sal

# Create the connection
engine = sal.create_engine(
    "mysql+pymysql://root:sohilkhattar@127.0.0.1:3306/sales_db"
)

# %%
# Test the connection
conn = engine.connect()
print("Connected Successfully!")
# Out:
# Connected Successfully!

# %%
# Load DataFrame into MySQL
df.to_sql(
    name="orders",
    con=engine,
    if_exists="replace",
    index=False
)

print("Data Loaded Successfully!")
# Out:
# Data Loaded Successfully!
